# %%
import pandas as pd

# %%
q4 = pd.read_csv("2024q4/num.txt", delimiter="\t", encoding="utf-8")
q3 = pd.read_csv("2024q3/num.txt", delimiter="\t", encoding="utf-8")

# %%
print(q4["ddate"].value_counts().to_string())
# Out:
# ddate
# 20240930    1357187
# 20230930     811107
# 20231231     573950
# 20240630     187073
# 20230630     150222
#              ...
# 19960229          1
# 20050630          1
# 20120531          1
# 20100630          1
# 20100131          1
# Name: count, Length: 241, dtype: int64

# %%
date = 20240630
adsh =  "0001438133-24-000201"

smaller_q4 = q4[(q4["ddate"] == date) & (q4["adsh"] == adsh)].reset_index(drop=True)
smaller_q3 = q3[(q3["ddate"] == date) & (q3["adsh"] == adsh)].reset_index(drop=True)
print(smaller_q4[["tag", "value"]])
print(smaller_q3[["tag", "value"]])
# Out:
#                   tag         value
# 0  StockholdersEquity  2.338750e+08
# 1   SharesOutstanding  6.543500e+07
# 2  StockholdersEquity  1.260392e+09
# 3  StockholdersEquity  6.500000e+04
# 4  StockholdersEquity -1.253000e+06
# 5  StockholdersEquity -1.025329e+09
# Empty DataFrame
# Columns: [tag, value]
# Index: []

# %%
prevdf = pd.read_csv("2024q3/num.txt", delimiter="\t", encoding="utf-8")
print(prevdf["ddate"].value_counts().to_string())
# Out:
# ddate
# 20240630    1365566
# 20230630     807635
# 20231231     585842
# 20240331     163307
# 20230331     129352
# 20221231     127684
# 20230930      47963
# 20240731      47409
# 20230731      36077
# 20240531      25574
# 20220630      21327
# 20230531      18325
# 20240430      18021
# 20211231      17974
# 20230430      13347
# 20220331      10597
# 20240131      10571
# 20220930       9764
# 20240229       8500
# 20231031       8126
# 20230831       5610
# 20230228       4462
# 20231130       4257
# 20230131       4133
# 20220531       3621
# 20221031       2990
# 20240831       2796
# 20220731       2592
# 20210630       2355
# 20221130       2209
# 20220430       1924
# 20201231       1706
# 20220831       1572
# 20210930        931
# 20210331        832
# 20211031        635
# 20210430        565
# 20220228        535
# 20211130        495
# 20210531        416
# 20210831        367
# 20210731        347
# 20210228        325
# 20220131        312
# 20191231        206
# ...

# %%
company = df[df["ddate"] == 20240930].reset_index(drop=True)

print(len(company))
print(company.loc[3,:])
# Out:
# 1357187
# adsh         0001438133-24-000201
# tag         OtherAssetsNoncurrent
# version              us-gaap/2024
# ddate                    20240930
# qtrs                            0
# uom                           USD
# segments                      NaN
# coreg                         NaN
# value                  36447000.0
# footnote                      NaN
# Name: 3, dtype: object

# %%
num = pd.read_csv("2024q4/sub.txt", delimiter="\t", encoding="utf-8")

# %%
comnum = num[num["adsh"] == "0000950170-24-120982"].reset_index(drop=True)
print(comnum)
# Out:
#                    adsh      cik                          name     sic  \
# 0  0000950170-24-120982  1660334  VERRICA PHARMACEUTICALS INC.  2834.0
#
#   countryba stprba        cityba  zipba                  bas1       bas2  ...  \
# 0        US     PA  WEST CHESTER  19380  10 NORTH HIGH STREET  SUITE 200  ...
#
#        period      fy  fp     filed               accepted prevrpt detail  \
# 0  20240930.0  2024.0  Q3  20241105  2024-11-04 18:25:00.0       0      1
#
#                 instance nciks  aciks
# 0  vrca-20240930_htm.xml     1    NaN
#
# [1 rows x 36 columns]

# %%
print(num.loc[1,:])
# Out:
# adsh               0000950170-24-122438
# cik                             1720116
# name                   RED VIOLET, INC.
# sic                              7372.0
# countryba                            US
# stprba                               FL
# cityba                       BOCA RATON
# zipba                             33431
# bas1          2650 NORTH MILITARY TRAIL
# bas2                          SUITE 300
# baph                         5617574000
# countryma                            US
# stprma                               FL
# cityma                       BOCA RATON
# zipma                             33431
# mas1          2650 NORTH MILITARY TRAIL
# mas2                          SUITE 300
# countryinc                           US
# stprinc                              DE
# ein                           822408531
# former                              NaN
# changed                             NaN
# afs                               4-NON
# ...
